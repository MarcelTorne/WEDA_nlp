# %%
from utils import *

class_name_to_num = {'DESC': 0, 'ENTY':1, 'ABBR':2, 'HUM': 3, 'LOC': 4, 'NUM': 5}

def clean(input_file, output_file):
    lines = open(input_file, 'r').readlines()
    writer = open(output_file, 'w')
    for line in lines:
        parts = line[:-1].split(' ')
        tag = parts[0].split(':')[0]
        class_num = class_name_to_num[tag]
        sentence = get_only_chars(' '.join(parts[1:]))
        print(tag, class_num, sentence)
        output_line = str(class_num) + '\t' + sentence
        writer.write(output_line + '\n')
    writer.close()


if __name__ == "__main__":

    clean('trec/raw_train_orig.txt', 'trec/train_orig.txt')
    clean('trec/raw_test.txt', 'trec/test.txt')
# Out:
# how did serfdom develop in and then leave russia
# DESC 0 how did serfdom develop in and then leave russia
# what films featured the character popeye doyle
# ENTY 1 what films featured the character popeye doyle
# how can i find a list of celebrities real names
# DESC 0 how can i find a list of celebrities real names
# what fowl grabs the spotlight after the chinese year of the monkey
# ENTY 1 what fowl grabs the spotlight after the chinese year of the monkey
# what is the full form of com
# ABBR 2 what is the full form of com
# what contemptible scoundrel stole the cork from my lunch
# HUM 3 what contemptible scoundrel stole the cork from my lunch
# what team did baseball is st louis browns become
# HUM 3 what team did baseball is st louis browns become
# what is the oldest profession
# HUM 3 what is the oldest profession
# what are liver enzymes
# DESC 0 what are liver enzymes
# name the scar faced bounty hunter of the old west
# ...
